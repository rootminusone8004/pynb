# %% [markdown]
# # 🤖 Machine Learning Classifier & Diagnostics
# This notebook trains an ensemble classifier and evaluates test metrics.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

clf = RandomForestClassifier(n_estimators=100, random_state=42)
print("Model initialized successfully.")
# Out:
# Model initialized successfully.

# %% [markdown]
# ## Performance Evaluation Metrics

# %%
# Displaying precision, recall, and ROC-AUC
plot_classification_metrics(clf)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Diagnostic Check (Handling Out-of-Bounds)
# Testing intentional exception handling and traceback logging:

# %%
# Intentionally querying an index that does not exist
predictions = [0.94, 0.91, 0.925]
print(predictions[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Intentionally querying an index that does not exist
#       2 predictions = [0.94, 0.91, 0.925]
# ----> 3 print(predictions[10])
# IndexError: list index out of range
